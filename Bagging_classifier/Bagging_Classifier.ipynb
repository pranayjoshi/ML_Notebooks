# %% [markdown]
# #### Objective:
#
# - Perform Bagging Classifier using sklearn package

# %% [markdown]
# #### Bagging (Bootstrap Aggregating)
#
# Given a standard original data set D of size n, bagging generates m new data sets D1, D2...Dm, each of size less than n, with replacement from an original sample.
# A bootstrap sample may have a few duplicate observations or records, as the sampling is done with replacement.
#
# Train the models on new training sets of the original dataset and then aggregate their individual predictions (either by voting or by averaging) to form a final prediction
#
# <img src="https://cdn.talentsprint.com/aiml/aiml_2020_b14_hyd/experiment_details_backup/bagging.png" width="700"/>

# %% [markdown]
# #### Dataset

# %%
# !wget https://cdn.talentsprint.com/aiml/Experiment_related_data/fruits_weight_sphercity.csv
# Out:
# --2020-07-23 09:13:57--  https://cdn.talentsprint.com/aiml/Experiment_related_data/fruits_weight_sphercity.csv
# Resolving cdn.talentsprint.com (cdn.talentsprint.com)... 172.105.34.236
# Connecting to cdn.talentsprint.com (cdn.talentsprint.com)|172.105.34.236|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1592 (1.6K) [application/octet-stream]
# Saving to: ‘fruits_weight_sphercity.csv’
#
# fruits_weight_spher 100%[===================>]   1.55K  --.-KB/s    in 0s
#
# 2020-07-23 09:13:59 (181 MB/s) - ‘fruits_weight_sphercity.csv’ saved [1592/1592]

# %% [markdown]
# #### Import Libraries

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import random
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### Read the dataset using Pandas and print first 5 records

# %%
df = pd.read_csv("./fruits_weight_sphercity.csv")
df.head()
# Out:
#     Color  Weight  Sphericity  labels
# 0     Red     200        0.40   apple
# 1  Orange     320        1.00  orange
# 2  Orange     310        0.95  orange
# 3     Red     220        0.45   apple
# 4     Red     230        0.50   apple

# %% [markdown]
# #### Convert categorical features into numeric values

# %%
label_enc = LabelEncoder().fit_transform

df["Color"], df["Weight"], df["Sphericity"], df["labels"] = label_enc(df['Color']), label_enc(df['Weight']), label_enc(df['Sphericity']), label_enc(df['labels'])

# %% [markdown]
# #### Identify the features and labels of dataset

# %%
features = df[['Color', 'Weight', 'Sphericity']]
labels = df[['labels']]
features.shape, labels.shape
# Out:
#    Color  Weight  Sphericity
# 0      3       0           8
# 1      2      32          38
# 2      2      28          36
# 3      3       5          13
# 4      3       7          18
# ((69, 3), (69, 1))

# %% [markdown]
# #### Split the data into train and test data

# %%
# Create a train and test parts with train_test_split function. test_size is 30%
X_train, X_test, Y_train, Y_test = train_test_split(features, labels, test_size = 30)

# %% [markdown]
# #### Perform Bagging Classifier using Sklearn

# %%
base_cls = DecisionTreeClassifier() 

  
# bagging classifier 
bag = BaggingClassifier(base_estimator = base_cls)

# %%
bag.fit(X_train, Y_train) # Fit the model using train data
print(bag.score(X_test,Y_test)) # Get the accuracy of test data
# Out:
# 0.8666666666666667
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
